# %%
from flask import Flask, request, jsonify, send_file
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from bs4 import BeautifulSoup
import requests
import pandas as pd
import os

# %%
with open('cons.txt', 'r') as file:
    lines = file.readlines()

data = [line.strip().split(';') for line in lines]
df = pd.DataFrame(data, columns=['input', 'label','extra'])

# %%
with open('confirmshaming.txt', 'r') as file:
    lines = file.readlines()

data = [line.strip().split(';') for line in lines]
df = pd.DataFrame(data, columns=['input', 'label'])

# %%
with open('cons.txt', 'r') as file:
    lines = file.readlines()

data = [line.strip().split(';') for line in lines]
df1 = pd.DataFrame(data, columns=['input', 'label','extra'])
df1 = df1.drop('extra', axis=1)

# %%
df1
# Out:
#                                                  input      label
# 0                      No, I don't want to save money    negative
# 1                Yes, sign me up for exclusive offers!   positive
# 2        No, I don't care about saving time and money.  negative"
# 3                   Yes, I want to subscribe and save!    postive
# 4            No, I don't want to improve your service.   negative
# ..                                                 ...        ...
# 339  Upgrade to premium for priority customer suppo...   positive
# 340              No, I'm fine with standard support.     negative
# 341        Support our cause and help those in need.     positive
# 342                        No, I don't want to help.     negative
# 343  Sign up and receive exclusive access to events.     positive
#
# [344 rows x 2 columns]

# %%
t=[df,df1]
da=pd.concat(t)
da
# Out:
#                                                  input     label
# 0                 No, I don't care about saving money.  negative
# 1    I'd rather pay full price because I don't want...  negative
# 2               No, I love missing out on great deals.  negative
# 3    I want to keep spending more. No discounts for...  negative
# 4    I prefer staying uninformed. No, I don't want ...  negative
# ..                                                 ...       ...
# 339  Upgrade to premium for priority customer suppo...  positive
# 340              No, I'm fine with standard support.    negative
# 341        Support our cause and help those in need.    positive
# 342                        No, I don't want to help.    negative
# 343  Sign up and receive exclusive access to events.    positive
#
# [1251 rows x 2 columns]
